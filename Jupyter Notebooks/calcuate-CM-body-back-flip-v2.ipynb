# %% [markdown]
# # Calculate CM of the body for a back flip
#
# ## Josh Berg and Aaron Titus, High Point University

# %% [markdown]
# ## Description
#
# The purpose of this program is to read data for position (x,y) and time (t) for forearm (with hand), upper arm, trunk, thigh, lower leg, and head. It assumes the arms and legs are parallel. It uses Dempster's body segment parameters.
#
# Units are meters.
#
# Segmental mass as ratio of total mass.
#
# | head | trunk | upper arm | forearm and hand | thigh | lower leg |
# | --- | --- | --- | --- | --- | --- |
# | .0810 | .497 | .028 | .022 | .1 | .0465 |
#
# Robertson, Gordon, Graham Caldwell, Joseph Hamill, Gary Kamen, and Saunders Whittlesey. Research Methods in Biomechanics . N.p.: Human Kinetics , 2004. Print.

# %% [markdown]
# ## Using pandas to read data from a text file

# %% [markdown]
# ## Back Flip Trial 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #used for graphing

# %%
#show graphs inline (do not use for print publication quality graphs)
# %matplotlib inline

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('back-flip-trial1.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  x_head  y_head  x_trunk  y_trunk  x_upper_arm  y_upper_arm  \
# 0  0.0167   0.195    1.22  -0.0403    0.938      0.00171         1.09
# 1  0.0333   0.195    1.21  -0.0457    0.916     -0.00950         1.05
# 2  0.0500   0.191    1.23  -0.0632    0.939     -0.04640         1.07
# 3  0.0667   0.177    1.24  -0.0682    0.937     -0.04340         1.03
# 4  0.0833   0.172    1.28  -0.0511    0.925     -0.03370         1.01
#
#    x_forearm  y_forearm  x_thigh  y_thigh    x_leg  y_leg
# 0     -0.326      1.140  -0.0861    0.622 -0.00216  0.272
# 1     -0.334      1.060  -0.0784    0.612  0.00339  0.275
# 2     -0.343      0.983  -0.0712    0.607  0.02480  0.264
# 3     -0.340      0.871  -0.0616    0.609  0.03500  0.268
# 4     -0.283      0.783  -0.0491    0.603  0.03970  0.282

# %%
Mlbs = 165 #total weight in pounds
M = Mlbs/2.2 #total mass in kg
segmass_percent=np.array([.0810 , .497 , 2*.028 , 2*.022 , 2*.1 , 2*.0465])
segmass=segmass_percent*M
g=9.8
#print(M,np.sum(segmass),segmass)

# %%
# Column heading full names
data_labels= [
    't (s)',
    'x of head (m)',
    'y of head (m)',
    'x of trunk (m)',
    'y of trunk (m)',
    'x of upper arm (m)',
    'y of upper arm (m)',
    'x of forearm+hand (m)',
    'y of forearm+hand (m)',
    'x of thigh (m)',
    'y of thigh (m)',
    'x of lower leg (m)',
    'y of lower leg (m)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (94, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (94,)

# %%
#create a x array for all rows
x_headarray = np.array(df_all['x_head'].tolist()) #create array
x_headarray.shape
y_headarray = np.array(df_all['y_head'].tolist()) #create array
y_headarray.shape


x_trunk = np.array(df_all['x_trunk'].tolist()) #create array
x_trunk.shape
y_trunk = np.array(df_all['y_trunk'].tolist()) #create array
y_trunk.shape

x_upper_arm = np.array(df_all['x_upper_arm'].tolist()) #create array
x_upper_arm.shape
y_upper_arm = np.array(df_all['y_upper_arm'].tolist()) #create array
y_upper_arm.shape

x_forearm = np.array(df_all['x_forearm'].tolist()) #create array
x_forearm.shape
y_forearm = np.array(df_all['y_forearm'].tolist()) #create array
y_forearm.shape

x_thigh = np.array(df_all['x_thigh'].tolist()) #create array
x_thigh.shape
y_thigh = np.array(df_all['y_thigh'].tolist()) #create array
y_thigh.shape

x_leg = np.array(df_all['x_leg'].tolist()) #create array
x_leg.shape
y_leg = np.array(df_all['y_leg'].tolist()) #create array
y_leg.shape
# Out:
# (94,)

# %%
# compute CM
#segmentdata=[[x_headarray,y_headarray],[x_trunk,y_trunk],[x_upper_arm,y_upper_arm],[x_forearm,y_forearm],[x_thigh,y_thigh],[x_leg,y_leg]]
xcmarray=(segmass[0]*x_headarray+segmass[1]*x_trunk+ segmass[2]*x_upper_arm+ segmass[3]*x_forearm+segmass[4]*x_thigh+segmass[5]*x_leg)/M
ycmarray=(segmass[0]*y_headarray+segmass[1]*y_trunk+ segmass[2]*y_upper_arm+ segmass[3]*y_forearm+segmass[4]*y_thigh+segmass[5]*y_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('X of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("x_cm (m)")
plt.plot(tarray,xcmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("y_cm (m)")
plt.plot(tarray,ycmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. X of Center of Mass')
plt.xlabel("x_cm (m)")
plt.ylabel("y_cm (m)")
plt.plot(xcmarray,ycmarray,'b-')
plt.show()

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('BF_Trial1_V.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  Vx_head  Vy_head  Vx_trunk  Vy_trunk  Vx_upper_arm  Vy_upper_arm  \
# 0  0.0167   -0.562   -0.843     0.429   -1.8300         0.298        -3.290
# 1  0.0333   -0.140    0.140    -0.689    0.0286        -1.440        -0.748
# 2  0.0500   -0.562    0.843    -0.677    0.6130        -1.020        -0.653
# 3  0.0667   -0.562    1.550     0.365   -0.4340         0.382        -1.750
# 4  0.0833   -1.120    1.400     0.145    0.2950         0.474        -0.722
#
#    Vx_forearm  Vy_forearm  Vx_thigh  Vy_thigh  Vx_leg  Vy_leg
# 0      -0.161     -0.8420     0.679  -0.64500   0.545  -0.193
# 1       0.198     -0.3970     0.448  -0.47000   0.810  -0.238
# 2       0.161      0.0761     0.505  -0.08720   0.950  -0.193
# 3      -0.407     -0.8230     0.664  -0.09470   0.446   0.549
# 4       0.000      0.0000     0.368   0.00755   0.234   0.265

# %%
# Column heading full names
data_labels= [
    't (s)',
    'Vx of head (m/s)',
    'Vy of head (m/s)',
    'Vx of trunk (m/s)',
    'Vy of trunk (m/s)',
    'Vx of upper arm (m/s)',
    'Vy of upper arm (m/s)',
    'Vx of forearm+hand (m/s)',
    'Vy of forearm+hand (m/s)',
    'Vx of thigh (m/s)',
    'Vy of thigh (m/s)',
    'Vx of lower leg (m/s)',
    'Vy of lower leg (m/s)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (94, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (94,)

# %%
#create a Vx and Vy array for all rows
Vx_headarray = np.array(df_all['Vx_head'].tolist()) #create array
Vx_headarray.shape
Vy_headarray = np.array(df_all['Vy_head'].tolist()) #create array
Vy_headarray.shape


Vx_trunk = np.array(df_all['Vx_trunk'].tolist()) #create array
Vx_trunk.shape
Vy_trunk = np.array(df_all['Vy_trunk'].tolist()) #create array
Vy_trunk.shape

Vx_upper_arm = np.array(df_all['Vx_upper_arm'].tolist()) #create array
Vx_upper_arm.shape
Vy_upper_arm = np.array(df_all['Vy_upper_arm'].tolist()) #create array
Vy_upper_arm.shape

Vx_forearm = np.array(df_all['Vx_forearm'].tolist()) #create array
Vx_forearm.shape
Vy_forearm = np.array(df_all['Vy_forearm'].tolist()) #create array
Vy_forearm.shape

Vx_thigh = np.array(df_all['Vx_thigh'].tolist()) #create array
Vx_thigh.shape
Vy_thigh = np.array(df_all['Vy_thigh'].tolist()) #create array
Vy_thigh.shape

Vx_leg = np.array(df_all['Vx_leg'].tolist()) #create array
Vx_leg.shape
Vy_leg = np.array(df_all['Vy_leg'].tolist()) #create array
Vy_leg.shape
# Out:
# (94,)

# %%
# compute CM
#segmentdata=[[Vx_headarray,Vy_headarray],[Vx_trunk,y_trunk],[Vx_upper_arm,Vy_upper_arm],[Vx_forearm,Vy_forearm],[Vx_thigh,Vy_thigh],[Vx_leg,Vy_leg]]
Vxcmarray=(segmass[0]*Vx_headarray+segmass[1]*Vx_trunk+ segmass[2]*Vx_upper_arm+ segmass[3]*Vx_forearm+segmass[4]*Vx_thigh+segmass[5]*Vx_leg)/M
Vycmarray=(segmass[0]*Vy_headarray+segmass[1]*Vy_trunk+ segmass[2]*Vy_upper_arm+ segmass[3]*Vy_forearm+segmass[4]*Vy_thigh+segmass[5]*Vy_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('Vx of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vx_cm (m/s)")
plt.plot(tarray,Vxcmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Vy of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vy_cm (m/s)")
plt.plot(tarray,Vycmarray,'b-')
plt.show()

# %% [markdown]
# ### Calculate slope
#
# Calculate the slope of $v_x(t)$ and $v_y(t)$ for $t>0.02$ s and $t<0.3$ s.

# %%
from scipy.optimize import curve_fit

# %%
#find indices for range of times
t_after = np.where(tarray > 0.02)[0]
t_before = np.where(tarray < 0.3)[0]
print("t_i = ",tarray[t_after[0]])
print("t_f = ",tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-1: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1
#print(len(t_inair))
#print(len(vy_inair))

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) for CM while jumping')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()

Ffloor_y=M*mbest+M*g
print("F_floor_y (N) = ",Ffloor_y)
# Out:
# t_i =  0.0333
# t_f =  0.283
# Best fit: m= 11.7049245069  and b= -0.725012447805
# F_floor_y (N) =  1612.86933801

# %%
#find indices for range of times
t_after = np.where(tarray > 0.316)[0]
t_before = np.where(tarray < 0.984)[0]
print(tarray[t_after[0]])
print(tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-1: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) in the air')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()
# Out:
# 0.317
# 0.983
# Best fit: m= -8.23278521679  and b= 4.68510162089

# %%
#find indices for range of times
t_after = np.where(tarray > 0.96)[0]
t_before = np.where(tarray < 1.15)[0]
print("t_i = ",tarray[t_after[0]])
print("t_f = ",tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]-1 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-1: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1
#print(len(t_inair))
#print(len(vy_inair))

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) for CM while landing')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()

Ffloor_y=M*mbest+M*g
print("F_floor_y (N) = ",Ffloor_y,M*9.8)
# Out:
# t_i =  0.967
# t_f =  1.13
# Best fit: m= 28.6539081859  and b= -29.7129083906
# F_floor_y (N) =  2884.04311395 735.0

# %%
# Momentum 
Px_total = M*Vxcmarray
Py_total = M*Vycmarray 

# Angular Momentum is <0,0,Rx*Py - Ry*Px>
Lz_head = ((x_headarray - xcmarray)*segmass[0]*Vy_headarray - (y_headarray - ycmarray)*segmass[0]*Vx_headarray)
Lz_trunk = ((x_trunk - xcmarray)*segmass[1]*Vy_trunk - (y_trunk - ycmarray)*segmass[1]*Vx_trunk)
Lz_upper_arm = ((x_upper_arm - xcmarray)*segmass[2]*Vy_upper_arm - (y_upper_arm - ycmarray)*segmass[2]*Vx_upper_arm)
Lz_forearm = ((x_forearm - xcmarray)*segmass[3]*Vy_forearm - (y_forearm - ycmarray)*segmass[3]*Vx_forearm)
Lz_thigh = ((x_thigh - xcmarray)*segmass[4]*Vy_thigh - (y_thigh - ycmarray)*segmass[4]*Vx_thigh)
Lz_leg = ((x_leg - xcmarray)*segmass[5]*Vy_leg - (y_leg - ycmarray)*segmass[5]*Vx_leg)

Lz_Rotation = Lz_head + Lz_trunk + Lz_upper_arm + Lz_forearm + Lz_thigh + Lz_leg

# %%
#plot graph
fig2 = plt.figure()
plt.title('Rotational Angular Momentum vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Rotational Angular Momentum (kg*m^2/s)")
plt.plot(tarray,Lz_Rotation,'b-')
plt.show()

# %%
#find indices for range of times
t_after = np.where(tarray > 0.15)[0]
t_before = np.where(tarray < .35)[0]
print("t_i = ",tarray[t_after[0]])
print("t_f = ",tarray[t_before[-1]])

#create new lists
t_inair=[]
Lz_inair=[]
i=t_after[0]+1 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]+1: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    Lz_inair.append(Lz_Rotation[int(i)])
    i=i+1

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(Lz_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for L_z_rot(t) while jumping')
plt.xlabel('t (s)')
plt.ylabel('L_z,rot (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()

nettorque=mbest
print("Net Torqe (N m) = ",nettorque)
# Out:
# t_i =  0.167
# t_f =  0.333
# Best fit: m= 246.290571407  and b= -43.9459804289
# Net Torqe (N m) =  246.290571407

# %%
#find indices for range of times
t_after = np.where(tarray > 0.6)[0]
t_before = np.where(tarray < .9)[0]
print("t_i = ",tarray[t_after[0]])
print("t_f = ",tarray[t_before[-1]])

#create new lists
t_inair=[]
Lz_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]+0: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    Lz_inair.append(Lz_Rotation[int(i)])
    i=i+1

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(Lz_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for L_z_rot(t) while in the air')
plt.xlabel('t (s)')
plt.ylabel('L_z,rot (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()

nettorque=mbest
print("Net Torqe (N m) = ",nettorque)
# Out:
# t_i =  0.617
# t_f =  0.883
# Best fit: m= 3.45128810585  and b= 27.4031498603
# Net Torqe (N m) =  3.45128810585

# %%
#find indices for range of times
t_after = np.where(tarray > 0.9)[0]
t_before = np.where(tarray < 1.1)[0]
print("t_i = ",tarray[t_after[0]])
print("t_f = ",tarray[t_before[-1]])

#create new lists
t_inair=[]
Lz_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]+0: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    Lz_inair.append(Lz_Rotation[int(i)])
    i=i+1

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(Lz_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for L_z_rot(t) while landing')
plt.xlabel('t (s)')
plt.ylabel('L_z,rot (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()

nettorque=mbest
print("Net Torqe (N m) = ",nettorque)
# Out:
# t_i =  0.917
# t_f =  1.08
# Best fit: m= -221.108621249  and b= 235.370277641
# Net Torqe (N m) =  -221.108621249

# %% [markdown]
# ## Back Flip Trial 2

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('back-flip-trial2.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  x_head  y_head  x_trunk  y_trunk  x_upper_arm  y_upper_arm  \
# 0  0.0167   0.256    1.33  0.06150     1.12      0.06570         1.27
# 1  0.0333   0.250    1.31  0.03860     1.06      0.04210         1.22
# 2  0.0500   0.261    1.28  0.04620     1.04      0.04350         1.18
# 3  0.0667   0.239    1.28  0.02710     1.03      0.02300         1.15
# 4  0.0833   0.239    1.29  0.00205     1.01     -0.00865         1.12
#
#    x_forearm  y_forearm  x_thigh  y_thigh    x_leg  y_leg
# 0     -0.265       1.43  -0.0967    0.696 -0.02910  0.282
# 1     -0.280       1.36  -0.0871    0.659 -0.01650  0.276
# 2     -0.310       1.28  -0.0823    0.650 -0.00103  0.273
# 3     -0.318       1.19  -0.0703    0.637  0.01700  0.281
# 4     -0.359       1.10  -0.0647    0.620  0.01790  0.269

# %%
# Column heading full names
data_labels= [
    't (s)',
    'x of head (m)',
    'y of head (m)',
    'x of trunk (m)',
    'y of trunk (m)',
    'x of upper arm (m)',
    'y of upper arm (m)',
    'x of forearm+hand (m)',
    'y of forearm+hand (m)',
    'x of thigh (m)',
    'y of thigh (m)',
    'x of lower leg (m)',
    'y of lower leg (m)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (94, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (94,)

# %%
#create a x array for all rows
x_headarray = np.array(df_all['x_head'].tolist()) #create array
x_headarray.shape
y_headarray = np.array(df_all['y_head'].tolist()) #create array
y_headarray.shape


x_trunk = np.array(df_all['x_trunk'].tolist()) #create array
x_trunk.shape
y_trunk = np.array(df_all['y_trunk'].tolist()) #create array
y_trunk.shape

x_upper_arm = np.array(df_all['x_upper_arm'].tolist()) #create array
x_upper_arm.shape
y_upper_arm = np.array(df_all['y_upper_arm'].tolist()) #create array
y_upper_arm.shape

x_forearm = np.array(df_all['x_forearm'].tolist()) #create array
x_forearm.shape
y_forearm = np.array(df_all['y_forearm'].tolist()) #create array
y_forearm.shape

x_thigh = np.array(df_all['x_thigh'].tolist()) #create array
x_thigh.shape
y_thigh = np.array(df_all['y_thigh'].tolist()) #create array
y_thigh.shape

x_leg = np.array(df_all['x_leg'].tolist()) #create array
x_leg.shape
y_leg = np.array(df_all['y_leg'].tolist()) #create array
y_leg.shape
# Out:
# (94,)

# %%
# compute CM
#segmentdata=[[x_headarray,y_headarray],[x_trunk,y_trunk],[x_upper_arm,y_upper_arm],[x_forearm,y_forearm],[x_thigh,y_thigh],[x_leg,y_leg]]
xcmarray=(segmass[0]*x_headarray+segmass[1]*x_trunk+ segmass[2]*x_upper_arm+ segmass[3]*x_forearm+segmass[4]*x_thigh+segmass[5]*x_leg)/M
ycmarray=(segmass[0]*y_headarray+segmass[1]*y_trunk+ segmass[2]*y_upper_arm+ segmass[3]*y_forearm+segmass[4]*y_thigh+segmass[5]*y_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('X of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("x_cm (m)")
plt.plot(tarray,xcmarray,'b-',tarray,x_leg,'r-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("y_cm (m)")
plt.plot(tarray,ycmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. X of Center of Mass')
plt.xlabel("x_cm (m)")
plt.ylabel("y_cm (m)")
plt.plot(xcmarray,ycmarray,'b-')
plt.show()

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('BF_Trial2_V.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#        t  Vx_head  Vy_head  Vx_trunk  Vy_trunk  Vx_upper_arm  Vy_upper_arm  \
# 0  0.017   -0.167   -2.000    -0.770    -2.670        -0.739         -2.59
# 1  0.033    0.167   -1.500    -0.459    -2.510        -0.667         -2.52
# 2  0.050   -0.333   -0.667    -0.344    -0.989        -0.573         -2.00
# 3  0.067   -0.667    0.167    -1.330    -0.759        -1.560         -1.95
# 4  0.083   -0.667   -0.167    -0.585     0.000        -1.000         -1.45
#
#    Vx_forearm  Vy_forearm  Vx_thigh  Vy_thigh  Vx_leg  Vy_leg
# 0      -0.833       -3.75    -1.510    -0.134   0.431  -0.069
# 1      -1.350       -4.26    -1.370     0.433   0.842  -0.258
# 2      -1.120       -4.98    -0.684     0.505   1.010   0.163
# 3      -1.450       -5.54    -0.900     0.527   0.568  -0.121
# 4      -0.773       -5.83    -0.289     0.550   0.336  -0.447

# %%
# Column heading full names
data_labels= [
    't (s)',
    'Vx of head (m/s)',
    'Vy of head (m/s)',
    'Vx of trunk (m/s)',
    'Vy of trunk (m/s)',
    'Vx of upper arm (m/s)',
    'Vy of upper arm (m/s)',
    'Vx of forearm+hand (m/s)',
    'Vy of forearm+hand (m/s)',
    'Vx of thigh (m/s)',
    'Vy of thigh (m/s)',
    'Vx of lower leg (m/s)',
    'Vy of lower leg (m/s)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (94, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (94,)

# %%
#create a Vx and Vy array for all rows
Vx_headarray = np.array(df_all['Vx_head'].tolist()) #create array
Vx_headarray.shape
Vy_headarray = np.array(df_all['Vy_head'].tolist()) #create array
Vy_headarray.shape


Vx_trunk = np.array(df_all['Vx_trunk'].tolist()) #create array
Vx_trunk.shape
Vy_trunk = np.array(df_all['Vy_trunk'].tolist()) #create array
Vy_trunk.shape

Vx_upper_arm = np.array(df_all['Vx_upper_arm'].tolist()) #create array
Vx_upper_arm.shape
Vy_upper_arm = np.array(df_all['Vy_upper_arm'].tolist()) #create array
Vy_upper_arm.shape

Vx_forearm = np.array(df_all['Vx_forearm'].tolist()) #create array
Vx_forearm.shape
Vy_forearm = np.array(df_all['Vy_forearm'].tolist()) #create array
Vy_forearm.shape

Vx_thigh = np.array(df_all['Vx_thigh'].tolist()) #create array
Vx_thigh.shape
Vy_thigh = np.array(df_all['Vy_thigh'].tolist()) #create array
Vy_thigh.shape

Vx_leg = np.array(df_all['Vx_leg'].tolist()) #create array
Vx_leg.shape
Vy_leg = np.array(df_all['Vy_leg'].tolist()) #create array
Vy_leg.shape
# Out:
# (94,)

# %%
# compute CM
#segmentdata=[[Vx_headarray,Vy_headarray],[Vx_trunk,y_trunk],[Vx_upper_arm,Vy_upper_arm],[Vx_forearm,Vy_forearm],[Vx_thigh,Vy_thigh],[Vx_leg,Vy_leg]]
Vxcmarray=(segmass[0]*Vx_headarray+segmass[1]*Vx_trunk+ segmass[2]*Vx_upper_arm+ segmass[3]*Vx_forearm+segmass[4]*Vx_thigh+segmass[5]*Vx_leg)/M
Vycmarray=(segmass[0]*Vy_headarray+segmass[1]*Vy_trunk+ segmass[2]*Vy_upper_arm+ segmass[3]*Vy_forearm+segmass[4]*Vy_thigh+segmass[5]*Vy_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('Vx of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vx_cm (m/s)")
plt.plot(tarray,Vxcmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Vy of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vy_cm (m/s)")
plt.plot(tarray,Vycmarray,'b-')
plt.show()

# %% [markdown]
# ### Calculate slope
#
# Calculate the slope of $v_x(t)$ and $v_y(t)$ for $t>0.381$ s and $t<1.018$ s.

# %%
from scipy.optimize import curve_fit

# %%
#find indices for range of times
t_after = np.where(tarray > 0.381)[0]
t_before = np.where(tarray < 0.72)[0]
print(tarray[t_after[0]])
print(tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-1: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1
print(len(t_inair))
print(len(vy_inair))

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) for CM while in air')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()
# Out:
# 0.383
# 0.717
# 19
# 19
# Best fit: m= -9.93982546905  and b= 5.39252670936

# %%
# Momentum 
Px_total = M*Vxcmarray
Py_total = M*Vycmarray 

# Angular Momentum is <0,0,Rx*Py - Ry*Px>
Lz_head = ((x_headarray - xcmarray)*segmass[0]*Vy_headarray - (y_headarray - ycmarray)*segmass[0]*Vx_headarray)*M
Lz_trunk = ((x_trunk - xcmarray)*segmass[1]*Vy_trunk - (y_trunk - ycmarray)*segmass[1]*Vx_trunk)*M
Lz_upper_arm = ((x_upper_arm - xcmarray)*segmass[2]*Vy_upper_arm - (y_upper_arm - ycmarray)*segmass[2]*Vx_upper_arm)*M
Lz_forearm = ((x_forearm - xcmarray)*segmass[3]*Vy_forearm - (y_forearm - ycmarray)*segmass[3]*Vx_forearm)*M
Lz_thigh = ((x_thigh - xcmarray)*segmass[4]*Vy_thigh - (y_thigh - ycmarray)*segmass[4]*Vx_thigh)*M
Lz_leg = ((x_leg - xcmarray)*segmass[5]*Vy_leg - (y_leg - ycmarray)*segmass[5]*Vx_leg)*M

Lz_Rotation = Lz_head + Lz_trunk + Lz_upper_arm + Lz_forearm + Lz_thigh + Lz_leg

# %%
#plot graph
fig2 = plt.figure()
plt.title('Rotational Angular Momentum vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Rotational Angular Momentum (kg*m^2/s)")
plt.plot(tarray,Lz_Rotation,'b-')
plt.show()

# %% [markdown]
# ## Back Flip Trial 3

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('back-flip-trial3.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  x_head  y_head  x_trunk  y_trunk  x_upper_arm  y_upper_arm  \
# 0  0.0167   0.196    1.20   0.0145    0.985      -0.0264        1.100
# 1  0.0333   0.185    1.19   0.0187    0.974      -0.0236        1.070
# 2  0.0500   0.179    1.20   0.0153    0.987      -0.0291        1.050
# 3  0.0667   0.168    1.22   0.0090    0.976      -0.0430        1.010
# 4  0.0833   0.151    1.24  -0.0240    0.980      -0.0652        0.994
#
#    x_forearm  y_forearm  x_thigh  y_thigh    x_leg  y_leg
# 0     -0.349      1.160  -0.0738    0.606 -0.00699  0.261
# 1     -0.347      1.090  -0.0777    0.600  0.00576  0.261
# 2     -0.373      0.966  -0.0744    0.593  0.01360  0.249
# 3     -0.365      0.873  -0.0601    0.580  0.01510  0.246
# 4     -0.309      0.779  -0.0459    0.578  0.03100  0.241

# %%
# Column heading full names
data_labels= [
    't (s)',
    'x of head (m)',
    'y of head (m)',
    'x of trunk (m)',
    'y of trunk (m)',
    'x of upper arm (m)',
    'y of upper arm (m)',
    'x of forearm+hand (m)',
    'y of forearm+hand (m)',
    'x of thigh (m)',
    'y of thigh (m)',
    'x of lower leg (m)',
    'y of lower leg (m)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (83, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (83,)

# %%
#create a x array for all rows
x_headarray = np.array(df_all['x_head'].tolist()) #create array
x_headarray.shape
y_headarray = np.array(df_all['y_head'].tolist()) #create array
y_headarray.shape


x_trunk = np.array(df_all['x_trunk'].tolist()) #create array
x_trunk.shape
y_trunk = np.array(df_all['y_trunk'].tolist()) #create array
y_trunk.shape

x_upper_arm = np.array(df_all['x_upper_arm'].tolist()) #create array
x_upper_arm.shape
y_upper_arm = np.array(df_all['y_upper_arm'].tolist()) #create array
y_upper_arm.shape

x_forearm = np.array(df_all['x_forearm'].tolist()) #create array
x_forearm.shape
y_forearm = np.array(df_all['y_forearm'].tolist()) #create array
y_forearm.shape

x_thigh = np.array(df_all['x_thigh'].tolist()) #create array
x_thigh.shape
y_thigh = np.array(df_all['y_thigh'].tolist()) #create array
y_thigh.shape

x_leg = np.array(df_all['x_leg'].tolist()) #create array
x_leg.shape
y_leg = np.array(df_all['y_leg'].tolist()) #create array
y_leg.shape
# Out:
# (83,)

# %%
# compute CM
#segmentdata=[[x_headarray,y_headarray],[x_trunk,y_trunk],[x_upper_arm,y_upper_arm],[x_forearm,y_forearm],[x_thigh,y_thigh],[x_leg,y_leg]]
xcmarray=(segmass[0]*x_headarray+segmass[1]*x_trunk+ segmass[2]*x_upper_arm+ segmass[3]*x_forearm+segmass[4]*x_thigh+segmass[5]*x_leg)/M
ycmarray=(segmass[0]*y_headarray+segmass[1]*y_trunk+ segmass[2]*y_upper_arm+ segmass[3]*y_forearm+segmass[4]*y_thigh+segmass[5]*y_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('X of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("x_cm (m)")
plt.plot(tarray,xcmarray,'b-',tarray,x_leg,'r-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("y_cm (m)")
plt.plot(tarray,ycmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. X of Center of Mass')
plt.xlabel("x_cm (m)")
plt.ylabel("y_cm (m)")
plt.plot(xcmarray,ycmarray,'b-')
plt.show()

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('BF_Trial3_V.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  Vx_head  Vy_head  Vx_trunk  Vy_trunk  Vx_upper_arm  Vy_upper_arm  \
# 0  0.0170   -0.333   -0.500   -0.7810     0.448        0.2500         -2.16
# 1  0.0333   -0.500    0.000    0.0628     0.022       -0.0833         -1.42
# 2  0.0500   -0.500    0.999    0.0628    -0.292       -0.5830         -1.83
# 3  0.0667   -0.833    1.330   -0.2180    -1.180       -1.0800         -1.75
# 4  0.0833   -1.830    1.500   -0.1670    -1.850       -0.7490         -1.17
#
#    Vx_forearm  Vy_forearm  Vx_thigh  Vy_thigh  Vx_leg  Vy_leg
# 0       -4.97      -0.341   -0.0738     0.606   0.598 -0.4500
# 1       -5.95      -0.727   -0.0777     0.600   0.617 -0.3780
# 2       -6.55      -0.553   -0.0744     0.593   0.279 -0.4460
# 3       -5.60       1.930   -0.0601     0.580   0.522 -0.2340
# 4       -5.34       4.060   -0.0459     0.578   0.666 -0.0269

# %%
# Column heading full names
data_labels= [
    't (s)',
    'Vx of head (m/s)',
    'Vy of head (m/s)',
    'Vx of trunk (m/s)',
    'Vy of trunk (m/s)',
    'Vx of upper arm (m/s)',
    'Vy of upper arm (m/s)',
    'Vx of forearm+hand (m/s)',
    'Vy of forearm+hand (m/s)',
    'Vx of thigh (m/s)',
    'Vy of thigh (m/s)',
    'Vx of lower leg (m/s)',
    'Vy of lower leg (m/s)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (83, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (83,)

# %%
#create a Vx and Vy array for all rows
Vx_headarray = np.array(df_all['Vx_head'].tolist()) #create array
Vx_headarray.shape
Vy_headarray = np.array(df_all['Vy_head'].tolist()) #create array
Vy_headarray.shape


Vx_trunk = np.array(df_all['Vx_trunk'].tolist()) #create array
Vx_trunk.shape
Vy_trunk = np.array(df_all['Vy_trunk'].tolist()) #create array
Vy_trunk.shape

Vx_upper_arm = np.array(df_all['Vx_upper_arm'].tolist()) #create array
Vx_upper_arm.shape
Vy_upper_arm = np.array(df_all['Vy_upper_arm'].tolist()) #create array
Vy_upper_arm.shape

Vx_forearm = np.array(df_all['Vx_forearm'].tolist()) #create array
Vx_forearm.shape
Vy_forearm = np.array(df_all['Vy_forearm'].tolist()) #create array
Vy_forearm.shape

Vx_thigh = np.array(df_all['Vx_thigh'].tolist()) #create array
Vx_thigh.shape
Vy_thigh = np.array(df_all['Vy_thigh'].tolist()) #create array
Vy_thigh.shape

Vx_leg = np.array(df_all['Vx_leg'].tolist()) #create array
Vx_leg.shape
Vy_leg = np.array(df_all['Vy_leg'].tolist()) #create array
Vy_leg.shape
# Out:
# (83,)

# %%
# compute CM
#segmentdata=[[Vx_headarray,Vy_headarray],[Vx_trunk,y_trunk],[Vx_upper_arm,Vy_upper_arm],[Vx_forearm,Vy_forearm],[Vx_thigh,Vy_thigh],[Vx_leg,Vy_leg]]
Vxcmarray=(segmass[0]*Vx_headarray+segmass[1]*Vx_trunk+ segmass[2]*Vx_upper_arm+ segmass[3]*Vx_forearm+segmass[4]*Vx_thigh+segmass[5]*Vx_leg)/M
Vycmarray=(segmass[0]*Vy_headarray+segmass[1]*Vy_trunk+ segmass[2]*Vy_upper_arm+ segmass[3]*Vy_forearm+segmass[4]*Vy_thigh+segmass[5]*Vy_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('Vx of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vx_cm (m/s)")
plt.plot(tarray,Vxcmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Vy of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vy_cm (m/s)")
plt.plot(tarray,Vycmarray,'b-')
plt.show()

# %% [markdown]
# ### Calculate slope
#
# Calculate the slope of $v_x(t)$ and $v_y(t)$ for $t>0.316$ s and $t<0.968$ s.

# %%
from scipy.optimize import curve_fit

# %%
#find indices for range of times
t_after = np.where(tarray > 0.55)[0]
t_before = np.where(tarray < 0.9)[0]
print(tarray[t_after[0]])
print(tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-1: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1
print(len(t_inair))
print(len(vy_inair))

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) for CM while in air')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()
# Out:
# 0.567
# 0.883
# 18
# 18
# Best fit: m= -4.33684899003  and b= 3.33229731238

# %%
# Momentum 
Px_total = M*Vxcmarray
Py_total = M*Vycmarray 

# Angular Momentum is <0,0,Rx*Py - Ry*Px>
Lz_head = ((x_headarray - xcmarray)*segmass[0]*Vy_headarray - (y_headarray - ycmarray)*segmass[0]*Vx_headarray)*M
Lz_trunk = ((x_trunk - xcmarray)*segmass[1]*Vy_trunk - (y_trunk - ycmarray)*segmass[1]*Vx_trunk)*M
Lz_upper_arm = ((x_upper_arm - xcmarray)*segmass[2]*Vy_upper_arm - (y_upper_arm - ycmarray)*segmass[2]*Vx_upper_arm)*M
Lz_forearm = ((x_forearm - xcmarray)*segmass[3]*Vy_forearm - (y_forearm - ycmarray)*segmass[3]*Vx_forearm)*M
Lz_thigh = ((x_thigh - xcmarray)*segmass[4]*Vy_thigh - (y_thigh - ycmarray)*segmass[4]*Vx_thigh)*M
Lz_leg = ((x_leg - xcmarray)*segmass[5]*Vy_leg - (y_leg - ycmarray)*segmass[5]*Vx_leg)*M

Lz_Rotation = Lz_head + Lz_trunk + Lz_upper_arm + Lz_forearm + Lz_thigh + Lz_leg

# %%
#plot graph
fig2 = plt.figure()
plt.title('Rotational Angular Momentum vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Rotational Angular Momentum (kg*m^2/s)")
plt.plot(tarray,Lz_Rotation,'b-')
plt.show()

# %% [markdown]
# ## Front Flip Trial 1

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('front-flip-trial1.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  x_head  y_head  x_trunk  y_trunk  x_upper_arm  y_upper_arm  \
# 0  0.0167   0.180    1.51   0.0733     1.20        0.181         1.23
# 1  0.0333   0.194    1.53   0.0861     1.25        0.200         1.29
# 2  0.0500   0.213    1.55   0.1170     1.27        0.236         1.32
# 3  0.0667   0.233    1.60   0.1050     1.29        0.219         1.36
# 4  0.0833   0.240    1.61   0.1060     1.32        0.230         1.38
#
#    x_forearm  y_forearm   x_thigh  y_thigh    x_leg  y_leg
# 0      0.404       1.10 -0.000241    0.699 -0.00936  0.273
# 1      0.398       1.16  0.006450    0.725 -0.00366  0.292
# 2      0.421       1.21 -0.023600    0.760 -0.02130  0.331
# 3      0.434       1.25 -0.017400    0.784 -0.01760  0.356
# 4      0.476       1.30 -0.021600    0.816 -0.03630  0.373

# %%
# Column heading full names
data_labels= [
    't (s)',
    'x of head (m)',
    'y of head (m)',
    'x of trunk (m)',
    'y of trunk (m)',
    'x of upper arm (m)',
    'y of upper arm (m)',
    'x of forearm+hand (m)',
    'y of forearm+hand (m)',
    'x of thigh (m)',
    'y of thigh (m)',
    'x of lower leg (m)',
    'y of lower leg (m)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (81, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (81,)

# %%
#create a x array for all rows
x_headarray = np.array(df_all['x_head'].tolist()) #create array
x_headarray.shape
y_headarray = np.array(df_all['y_head'].tolist()) #create array
y_headarray.shape


x_trunk = np.array(df_all['x_trunk'].tolist()) #create array
x_trunk.shape
y_trunk = np.array(df_all['y_trunk'].tolist()) #create array
y_trunk.shape

x_upper_arm = np.array(df_all['x_upper_arm'].tolist()) #create array
x_upper_arm.shape
y_upper_arm = np.array(df_all['y_upper_arm'].tolist()) #create array
y_upper_arm.shape

x_forearm = np.array(df_all['x_forearm'].tolist()) #create array
x_forearm.shape
y_forearm = np.array(df_all['y_forearm'].tolist()) #create array
y_forearm.shape

x_thigh = np.array(df_all['x_thigh'].tolist()) #create array
x_thigh.shape
y_thigh = np.array(df_all['y_thigh'].tolist()) #create array
y_thigh.shape

x_leg = np.array(df_all['x_leg'].tolist()) #create array
x_leg.shape
y_leg = np.array(df_all['y_leg'].tolist()) #create array
y_leg.shape
# Out:
# (81,)

# %%
# compute CM
#segmentdata=[[x_headarray,y_headarray],[x_trunk,y_trunk],[x_upper_arm,y_upper_arm],[x_forearm,y_forearm],[x_thigh,y_thigh],[x_leg,y_leg]]
xcmarray=(segmass[0]*x_headarray+segmass[1]*x_trunk+ segmass[2]*x_upper_arm+ segmass[3]*x_forearm+segmass[4]*x_thigh+segmass[5]*x_leg)/M
ycmarray=(segmass[0]*y_headarray+segmass[1]*y_trunk+ segmass[2]*y_upper_arm+ segmass[3]*y_forearm+segmass[4]*y_thigh+segmass[5]*y_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('X of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("x_cm (m)")
plt.plot(tarray,xcmarray,'b-',tarray,x_leg,'r-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("y_cm (m)")
plt.plot(tarray,ycmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. X of Center of Mass')
plt.xlabel("x_cm (m)")
plt.ylabel("y_cm (m)")
plt.plot(xcmarray,ycmarray,'b-')
plt.show()

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('FF_Trial1_V.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#        t  Vx_head  Vy_head  Vx_trunk  Vy_trunk  Vx_upper_arm  Vy_upper_arm  \
# 0  0.017   -0.167   -2.000    -0.770    -2.670        -0.739         -2.59
# 1  0.033    0.167   -1.500    -0.459    -2.510        -0.667         -2.52
# 2  0.050   -0.333   -0.667    -0.344    -0.989        -0.573         -2.00
# 3  0.067   -0.667    0.167    -1.330    -0.759        -1.560         -1.95
# 4  0.083   -0.667   -0.167    -0.585     0.000        -1.000         -1.45
#
#    Vx_forearm  Vy_forearm  Vx_thigh  Vy_thigh  Vx_leg  Vy_leg
# 0      -0.833       -3.75    -1.510    -0.134   0.431  -0.069
# 1      -1.350       -4.26    -1.370     0.433   0.842  -0.258
# 2      -1.120       -4.98    -0.684     0.505   1.010   0.163
# 3      -1.450       -5.54    -0.900     0.527   0.568  -0.121
# 4      -0.773       -5.83    -0.289     0.550   0.336  -0.447

# %%
# Column heading full names
data_labels= [
    't (s)',
    'Vx of head (m/s)',
    'Vy of head (m/s)',
    'Vx of trunk (m/s)',
    'Vy of trunk (m/s)',
    'Vx of upper arm (m/s)',
    'Vy of upper arm (m/s)',
    'Vx of forearm+hand (m/s)',
    'Vy of forearm+hand (m/s)',
    'Vx of thigh (m/s)',
    'Vy of thigh (m/s)',
    'Vx of lower leg (m/s)',
    'Vy of lower leg (m/s)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (81, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (81,)

# %%
#create a Vx and Vy array for all rows
Vx_headarray = np.array(df_all['Vx_head'].tolist()) #create array
Vx_headarray.shape
Vy_headarray = np.array(df_all['Vy_head'].tolist()) #create array
Vy_headarray.shape


Vx_trunk = np.array(df_all['Vx_trunk'].tolist()) #create array
Vx_trunk.shape
Vy_trunk = np.array(df_all['Vy_trunk'].tolist()) #create array
Vy_trunk.shape

Vx_upper_arm = np.array(df_all['Vx_upper_arm'].tolist()) #create array
Vx_upper_arm.shape
Vy_upper_arm = np.array(df_all['Vy_upper_arm'].tolist()) #create array
Vy_upper_arm.shape

Vx_forearm = np.array(df_all['Vx_forearm'].tolist()) #create array
Vx_forearm.shape
Vy_forearm = np.array(df_all['Vy_forearm'].tolist()) #create array
Vy_forearm.shape

Vx_thigh = np.array(df_all['Vx_thigh'].tolist()) #create array
Vx_thigh.shape
Vy_thigh = np.array(df_all['Vy_thigh'].tolist()) #create array
Vy_thigh.shape

Vx_leg = np.array(df_all['Vx_leg'].tolist()) #create array
Vx_leg.shape
Vy_leg = np.array(df_all['Vy_leg'].tolist()) #create array
Vy_leg.shape
# Out:
# (81,)

# %%
# compute CM
#segmentdata=[[Vx_headarray,Vy_headarray],[Vx_trunk,y_trunk],[Vx_upper_arm,Vy_upper_arm],[Vx_forearm,Vy_forearm],[Vx_thigh,Vy_thigh],[Vx_leg,Vy_leg]]
Vxcmarray=(segmass[0]*Vx_headarray+segmass[1]*Vx_trunk+ segmass[2]*Vx_upper_arm+ segmass[3]*Vx_forearm+segmass[4]*Vx_thigh+segmass[5]*Vx_leg)/M
Vycmarray=(segmass[0]*Vy_headarray+segmass[1]*Vy_trunk+ segmass[2]*Vy_upper_arm+ segmass[3]*Vy_forearm+segmass[4]*Vy_thigh+segmass[5]*Vy_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('Vx of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vx_cm (m/s)")
plt.plot(tarray,Vxcmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Vy of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vy_cm (m/s)")
plt.plot(tarray,Vycmarray,'b-')
plt.show()

# %% [markdown]
# ### Calculate slope
#
# Calculate the slope of $v_x(t)$ and $v_y(t)$ for $t>0.682$ s and $t<1.11$ s.

# %%
from scipy.optimize import curve_fit

# %%
#find indices for range of times
t_after = np.where(tarray > 0.682)[0]
t_before = np.where(tarray < 1.11)[0]
print(tarray[t_after[0]])
print(tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-3: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1
print(len(t_inair))
print(len(vy_inair))

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) for CM while in air')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()
# Out:
# 0.683
# 1.1
# 22
# 22
# Best fit: m= -0.960371776216  and b= -0.523996851117

# %%
# Momentum 
Px_total = M*Vxcmarray
Py_total = M*Vycmarray 

# Angular Momentum is <0,0,Rx*Py - Ry*Px>
Lz_head = ((x_headarray - xcmarray)*segmass[0]*Vy_headarray - (y_headarray - ycmarray)*segmass[0]*Vx_headarray)*M
Lz_trunk = ((x_trunk - xcmarray)*segmass[1]*Vy_trunk - (y_trunk - ycmarray)*segmass[1]*Vx_trunk)*M
Lz_upper_arm = ((x_upper_arm - xcmarray)*segmass[2]*Vy_upper_arm - (y_upper_arm - ycmarray)*segmass[2]*Vx_upper_arm)*M
Lz_forearm = ((x_forearm - xcmarray)*segmass[3]*Vy_forearm - (y_forearm - ycmarray)*segmass[3]*Vx_forearm)*M
Lz_thigh = ((x_thigh - xcmarray)*segmass[4]*Vy_thigh - (y_thigh - ycmarray)*segmass[4]*Vx_thigh)*M
Lz_leg = ((x_leg - xcmarray)*segmass[5]*Vy_leg - (y_leg - ycmarray)*segmass[5]*Vx_leg)*M

Lz_Rotation = Lz_head + Lz_trunk + Lz_upper_arm + Lz_forearm + Lz_thigh + Lz_leg

# %%
#plot graph
fig2 = plt.figure()
plt.title('Rotational Angular Momentum vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Rotational Angular Momentum (kg*m^2/s)")
plt.plot(tarray,Lz_Rotation,'b-')
plt.show()

# %% [markdown]
# ## Front Flip Trial 2

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('front-flip-trial2.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  x_head  y_head  x_trunk  y_trunk  x_upper_arm  y_upper_arm  \
# 0  0.0167   0.341    1.50    0.169     1.30        0.284         1.38
# 1  0.0333   0.341    1.51    0.175     1.30        0.281         1.37
# 2  0.0500   0.365    1.49    0.255     1.25        0.279         1.34
# 3  0.0667   0.371    1.48    0.157     1.29        0.266         1.34
# 4  0.0833   0.371    1.46    0.169     1.28        0.262         1.33
#
#    x_forearm  y_forearm  x_thigh  y_thigh     x_leg  y_leg
# 0      0.476       1.24   0.0279    0.782  0.002470  0.323
# 1      0.467       1.22   0.0433    0.782  0.001530  0.333
# 2      0.457       1.19   0.1910    0.738 -0.000208  0.343
# 3      0.443       1.18   0.0431    0.788  0.014800  0.337
# 4      0.421       1.16   0.0645    0.775  0.017200  0.336

# %%
# Column heading full names
data_labels= [
    't (s)',
    'x of head (m)',
    'y of head (m)',
    'x of trunk (m)',
    'y of trunk (m)',
    'x of upper arm (m)',
    'y of upper arm (m)',
    'x of forearm+hand (m)',
    'y of forearm+hand (m)',
    'x of thigh (m)',
    'y of thigh (m)',
    'x of lower leg (m)',
    'y of lower leg (m)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (73, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (73,)

# %%
#create a x array for all rows
x_headarray = np.array(df_all['x_head'].tolist()) #create array
x_headarray.shape
y_headarray = np.array(df_all['y_head'].tolist()) #create array
y_headarray.shape


x_trunk = np.array(df_all['x_trunk'].tolist()) #create array
x_trunk.shape
y_trunk = np.array(df_all['y_trunk'].tolist()) #create array
y_trunk.shape

x_upper_arm = np.array(df_all['x_upper_arm'].tolist()) #create array
x_upper_arm.shape
y_upper_arm = np.array(df_all['y_upper_arm'].tolist()) #create array
y_upper_arm.shape

x_forearm = np.array(df_all['x_forearm'].tolist()) #create array
x_forearm.shape
y_forearm = np.array(df_all['y_forearm'].tolist()) #create array
y_forearm.shape

x_thigh = np.array(df_all['x_thigh'].tolist()) #create array
x_thigh.shape
y_thigh = np.array(df_all['y_thigh'].tolist()) #create array
y_thigh.shape

x_leg = np.array(df_all['x_leg'].tolist()) #create array
x_leg.shape
y_leg = np.array(df_all['y_leg'].tolist()) #create array
y_leg.shape
# Out:
# (73,)

# %%
# compute CM
#segmentdata=[[x_headarray,y_headarray],[x_trunk,y_trunk],[x_upper_arm,y_upper_arm],[x_forearm,y_forearm],[x_thigh,y_thigh],[x_leg,y_leg]]
xcmarray=(segmass[0]*x_headarray+segmass[1]*x_trunk+ segmass[2]*x_upper_arm+ segmass[3]*x_forearm+segmass[4]*x_thigh+segmass[5]*x_leg)/M
ycmarray=(segmass[0]*y_headarray+segmass[1]*y_trunk+ segmass[2]*y_upper_arm+ segmass[3]*y_forearm+segmass[4]*y_thigh+segmass[5]*y_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('X of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("x_cm (m)")
plt.plot(tarray,xcmarray,'b-',tarray,x_leg,'r-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("y_cm (m)")
plt.plot(tarray,ycmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. X of Center of Mass')
plt.xlabel("x_cm (m)")
plt.ylabel("y_cm (m)")
plt.plot(xcmarray,ycmarray,'b-')
plt.show()

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('FF_Trial2_V.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  Vx_head  Vy_head  Vx_trunk  Vy_trunk  Vx_upper_arm  Vy_upper_arm  \
# 0  0.0170    0.912   -0.547     0.299     0.654         0.428        -0.216
# 1  0.0333    0.730   -0.182    -1.460     2.560        -1.110        -0.153
# 2  0.0500    0.912   -0.912    -0.306    -0.533        -0.833        -0.450
# 3  0.0667    0.182   -0.912     0.859    -2.570        -0.360        -0.504
# 4  0.0833    0.182   -1.090    -0.696     0.760        -0.811        -0.391
#
#    Vx_forearm  Vy_forearm  Vx_thigh  Vy_thigh  Vx_leg  Vy_leg
# 0      -0.806      -0.431   0.84300     0.332  0.3180  0.6030
# 1      -0.591      -1.410   4.88000    -1.320 -0.0805  0.6030
# 2      -0.711      -1.110  -0.00604     0.179  0.3990  0.0997
# 3      -1.060      -0.934  -3.78000     1.120  0.5220 -0.2230
# 4      -1.460      -1.290   1.10000    -0.827  0.4990  0.0759

# %%
# Column heading full names
data_labels= [
    't (s)',
    'Vx of head (m/s)',
    'Vy of head (m/s)',
    'Vx of trunk (m/s)',
    'Vy of trunk (m/s)',
    'Vx of upper arm (m/s)',
    'Vy of upper arm (m/s)',
    'Vx of forearm+hand (m/s)',
    'Vy of forearm+hand (m/s)',
    'Vx of thigh (m/s)',
    'Vy of thigh (m/s)',
    'Vx of lower leg (m/s)',
    'Vy of lower leg (m/s)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (73, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (73,)

# %%
#create a Vx and Vy array for all rows
Vx_headarray = np.array(df_all['Vx_head'].tolist()) #create array
Vx_headarray.shape
Vy_headarray = np.array(df_all['Vy_head'].tolist()) #create array
Vy_headarray.shape


Vx_trunk = np.array(df_all['Vx_trunk'].tolist()) #create array
Vx_trunk.shape
Vy_trunk = np.array(df_all['Vy_trunk'].tolist()) #create array
Vy_trunk.shape

Vx_upper_arm = np.array(df_all['Vx_upper_arm'].tolist()) #create array
Vx_upper_arm.shape
Vy_upper_arm = np.array(df_all['Vy_upper_arm'].tolist()) #create array
Vy_upper_arm.shape

Vx_forearm = np.array(df_all['Vx_forearm'].tolist()) #create array
Vx_forearm.shape
Vy_forearm = np.array(df_all['Vy_forearm'].tolist()) #create array
Vy_forearm.shape

Vx_thigh = np.array(df_all['Vx_thigh'].tolist()) #create array
Vx_thigh.shape
Vy_thigh = np.array(df_all['Vy_thigh'].tolist()) #create array
Vy_thigh.shape

Vx_leg = np.array(df_all['Vx_leg'].tolist()) #create array
Vx_leg.shape
Vy_leg = np.array(df_all['Vy_leg'].tolist()) #create array
Vy_leg.shape
# Out:
# (73,)

# %%
# compute CM
#segmentdata=[[Vx_headarray,Vy_headarray],[Vx_trunk,y_trunk],[Vx_upper_arm,Vy_upper_arm],[Vx_forearm,Vy_forearm],[Vx_thigh,Vy_thigh],[Vx_leg,Vy_leg]]
Vxcmarray=(segmass[0]*Vx_headarray+segmass[1]*Vx_trunk+ segmass[2]*Vx_upper_arm+ segmass[3]*Vx_forearm+segmass[4]*Vx_thigh+segmass[5]*Vx_leg)/M
Vycmarray=(segmass[0]*Vy_headarray+segmass[1]*Vy_trunk+ segmass[2]*Vy_upper_arm+ segmass[3]*Vy_forearm+segmass[4]*Vy_thigh+segmass[5]*Vy_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('Vx of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vx_cm (m/s)")
plt.plot(tarray,Vxcmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Vy of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vy_cm (m/s)")
plt.plot(tarray,Vycmarray,'b-')
plt.show()

# %% [markdown]
# ### Calculate slope
#
# Calculate the slope of $v_x(t)$ and $v_y(t)$ for $t>0.482$ s and $t<0.91$ s.

# %%
from scipy.optimize import curve_fit

# %%
#find indices for range of times
t_after = np.where(tarray > 0.682)[0]
t_before = np.where(tarray < 1.11)[0]
print(tarray[t_after[0]])
print(tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-3: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1
print(len(t_inair))
print(len(vy_inair))

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) for CM while in air')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()
# Out:
# 0.683
# 1.1
# 22
# 22
# Best fit: m= 10.5445866111  and b= -9.56160532533

# %%
# Momentum 
Px_total = M*Vxcmarray
Py_total = M*Vycmarray 

# Angular Momentum is <0,0,Rx*Py - Ry*Px>
Lz_head = ((x_headarray - xcmarray)*segmass[0]*Vy_headarray - (y_headarray - ycmarray)*segmass[0]*Vx_headarray)*M
Lz_trunk = ((x_trunk - xcmarray)*segmass[1]*Vy_trunk - (y_trunk - ycmarray)*segmass[1]*Vx_trunk)*M
Lz_upper_arm = ((x_upper_arm - xcmarray)*segmass[2]*Vy_upper_arm - (y_upper_arm - ycmarray)*segmass[2]*Vx_upper_arm)*M
Lz_forearm = ((x_forearm - xcmarray)*segmass[3]*Vy_forearm - (y_forearm - ycmarray)*segmass[3]*Vx_forearm)*M
Lz_thigh = ((x_thigh - xcmarray)*segmass[4]*Vy_thigh - (y_thigh - ycmarray)*segmass[4]*Vx_thigh)*M
Lz_leg = ((x_leg - xcmarray)*segmass[5]*Vy_leg - (y_leg - ycmarray)*segmass[5]*Vx_leg)*M

Lz_Rotation = Lz_head + Lz_trunk + Lz_upper_arm + Lz_forearm + Lz_thigh + Lz_leg

# %%
#plot graph
fig2 = plt.figure()
plt.title('Rotational Angular Momentum vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Rotational Angular Momentum (kg*m^2/s)")
plt.plot(tarray,Lz_Rotation,'b-')
plt.show()

# %% [markdown]
# ## Front Flip Trial 3

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('front-flip-trial3.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  x_head  y_head  x_trunk  y_trunk  x_upper_arm  y_upper_arm  \
# 0  0.0167   0.221    1.52    0.105     1.30        0.225         1.39
# 1  0.0333   0.247    1.53    0.094     1.32        0.203         1.43
# 2  0.0500   0.260    1.56    0.116     1.32        0.226         1.42
# 3  0.0667   0.260    1.52    0.118     1.31        0.226         1.42
# 4  0.0833   0.286    1.51    0.144     1.31        0.239         1.40
#
#    x_forearm  y_forearm  x_thigh  y_thigh    x_leg  y_leg
# 0      0.424       1.31 -0.01790    0.758 -0.01340  0.311
# 1      0.429       1.32 -0.00308    0.784 -0.00709  0.331
# 2      0.422       1.32  0.00423    0.784 -0.00709  0.336
# 3      0.413       1.30  0.01910    0.793  0.00755  0.364
# 4      0.385       1.31  0.02460    0.797  0.02320  0.360

# %%
# Column heading full names
data_labels= [
    't (s)',
    'x of head (m)',
    'y of head (m)',
    'x of trunk (m)',
    'y of trunk (m)',
    'x of upper arm (m)',
    'y of upper arm (m)',
    'x of forearm+hand (m)',
    'y of forearm+hand (m)',
    'x of thigh (m)',
    'y of thigh (m)',
    'x of lower leg (m)',
    'y of lower leg (m)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (74, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (74,)

# %%
#create a x array for all rows
x_headarray = np.array(df_all['x_head'].tolist()) #create array
x_headarray.shape
y_headarray = np.array(df_all['y_head'].tolist()) #create array
y_headarray.shape


x_trunk = np.array(df_all['x_trunk'].tolist()) #create array
x_trunk.shape
y_trunk = np.array(df_all['y_trunk'].tolist()) #create array
y_trunk.shape

x_upper_arm = np.array(df_all['x_upper_arm'].tolist()) #create array
x_upper_arm.shape
y_upper_arm = np.array(df_all['y_upper_arm'].tolist()) #create array
y_upper_arm.shape

x_forearm = np.array(df_all['x_forearm'].tolist()) #create array
x_forearm.shape
y_forearm = np.array(df_all['y_forearm'].tolist()) #create array
y_forearm.shape

x_thigh = np.array(df_all['x_thigh'].tolist()) #create array
x_thigh.shape
y_thigh = np.array(df_all['y_thigh'].tolist()) #create array
y_thigh.shape

x_leg = np.array(df_all['x_leg'].tolist()) #create array
x_leg.shape
y_leg = np.array(df_all['y_leg'].tolist()) #create array
y_leg.shape
# Out:
# (74,)

# %%
# compute CM
#segmentdata=[[x_headarray,y_headarray],[x_trunk,y_trunk],[x_upper_arm,y_upper_arm],[x_forearm,y_forearm],[x_thigh,y_thigh],[x_leg,y_leg]]
xcmarray=(segmass[0]*x_headarray+segmass[1]*x_trunk+ segmass[2]*x_upper_arm+ segmass[3]*x_forearm+segmass[4]*x_thigh+segmass[5]*x_leg)/M
ycmarray=(segmass[0]*y_headarray+segmass[1]*y_trunk+ segmass[2]*y_upper_arm+ segmass[3]*y_forearm+segmass[4]*y_thigh+segmass[5]*y_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('X of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("x_cm (m)")
plt.plot(tarray,xcmarray,'b-',tarray,x_leg,'r-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("y_cm (m)")
plt.plot(tarray,ycmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Y of Center of Mass vs. X of Center of Mass')
plt.xlabel("x_cm (m)")
plt.ylabel("y_cm (m)")
plt.plot(xcmarray,ycmarray,'b-')
plt.show()

# %%
# Read data file and define dataframe object (df for dataframe)
df_all = pd.read_table('FF_Trial3_V.txt')

# %%
#print first five rows of data with the header
df_all.head()
# Out:
#         t  Vx_head  Vy_head  Vx_trunk  Vy_trunk  Vx_upper_arm  Vy_upper_arm  \
# 0  0.0170    1.160   -0.580     0.400     1.040        0.2430         1.410
# 1  0.0333    1.160    0.967     0.314     0.774        0.0249         0.858
# 2  0.0500    0.387   -0.193     0.713    -0.254        0.6890        -0.193
# 3  0.0667    0.774   -1.350     0.859    -0.400        0.4020        -0.580
# 4  0.0833    1.740    0.193     0.387    -0.653        0.0497        -1.190
#
#    Vx_forearm  Vy_forearm  Vx_thigh  Vy_thigh  Vx_leg  Vy_leg
# 0     -0.1930      0.2900     0.419     0.774   0.857   0.465
# 1     -0.0615      0.0439     0.664     0.774   0.774   0.188
# 2     -0.4750     -0.7210     0.664     0.283   0.993   0.439
# 3     -1.1100     -0.3160     0.612     0.419   0.716   0.909
# 4     -1.1800     -0.8170     0.805    -0.554  -0.439   1.190

# %%
# Column heading full names
data_labels= [
    't (s)',
    'Vx of head (m/s)',
    'Vy of head (m/s)',
    'Vx of trunk (m/s)',
    'Vy of trunk (m/s)',
    'Vx of upper arm (m/s)',
    'Vy of upper arm (m/s)',
    'Vx of forearm+hand (m/s)',
    'Vy of forearm+hand (m/s)',
    'Vx of thigh (m/s)',
    'Vy of thigh (m/s)',
    'Vx of lower leg (m/s)',
    'Vy of lower leg (m/s)',
]

# %%
#rows, columns of data table
df_all.shape
# Out:
# (74, 13)

# %%
#create a t array for all rows
tarray = np.array(df_all['t'].tolist()) #create array
tarray.shape
# Out:
# (74,)

# %%
#create a Vx and Vy array for all rows
Vx_headarray = np.array(df_all['Vx_head'].tolist()) #create array
Vx_headarray.shape
Vy_headarray = np.array(df_all['Vy_head'].tolist()) #create array
Vy_headarray.shape


Vx_trunk = np.array(df_all['Vx_trunk'].tolist()) #create array
Vx_trunk.shape
Vy_trunk = np.array(df_all['Vy_trunk'].tolist()) #create array
Vy_trunk.shape

Vx_upper_arm = np.array(df_all['Vx_upper_arm'].tolist()) #create array
Vx_upper_arm.shape
Vy_upper_arm = np.array(df_all['Vy_upper_arm'].tolist()) #create array
Vy_upper_arm.shape

Vx_forearm = np.array(df_all['Vx_forearm'].tolist()) #create array
Vx_forearm.shape
Vy_forearm = np.array(df_all['Vy_forearm'].tolist()) #create array
Vy_forearm.shape

Vx_thigh = np.array(df_all['Vx_thigh'].tolist()) #create array
Vx_thigh.shape
Vy_thigh = np.array(df_all['Vy_thigh'].tolist()) #create array
Vy_thigh.shape

Vx_leg = np.array(df_all['Vx_leg'].tolist()) #create array
Vx_leg.shape
Vy_leg = np.array(df_all['Vy_leg'].tolist()) #create array
Vy_leg.shape
# Out:
# (74,)

# %%
# compute CM
#segmentdata=[[Vx_headarray,Vy_headarray],[Vx_trunk,y_trunk],[Vx_upper_arm,Vy_upper_arm],[Vx_forearm,Vy_forearm],[Vx_thigh,Vy_thigh],[Vx_leg,Vy_leg]]
Vxcmarray=(segmass[0]*Vx_headarray+segmass[1]*Vx_trunk+ segmass[2]*Vx_upper_arm+ segmass[3]*Vx_forearm+segmass[4]*Vx_thigh+segmass[5]*Vx_leg)/M
Vycmarray=(segmass[0]*Vy_headarray+segmass[1]*Vy_trunk+ segmass[2]*Vy_upper_arm+ segmass[3]*Vy_forearm+segmass[4]*Vy_thigh+segmass[5]*Vy_leg)/M

# %%
#plot graph
fig2 = plt.figure()
plt.title('Vx of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vx_cm (m/s)")
plt.plot(tarray,Vxcmarray,'b-')
plt.show()

fig2 = plt.figure()
plt.title('Vy of Center of Mass vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Vy_cm (m/s)")
plt.plot(tarray,Vycmarray,'b-')
plt.show()

# %% [markdown]
# ### Calculate slope
#
# Calculate the slope of $v_x(t)$ and $v_y(t)$ for $t>0.532$ s and $t<0.984$ s.

# %%
from scipy.optimize import curve_fit

# %%
#find indices for range of times
t_after = np.where(tarray > 0.532)[0]
t_before = np.where(tarray < 0.984)[0]
print(tarray[t_after[0]])
print(tarray[t_before[-1]])

#create new lists
t_inair=[]
vy_inair=[]
i=t_after[0]+0 ## add an integer to increase the left edge of the time interval
while i<t_before[-1]-10: ## subtract an integer to decrease the right edge of the time interval
    t_inair.append(tarray[int(i)])
    vy_inair.append(Vycmarray[int(i)])
    i=i+1
print(len(t_inair))
print(len(vy_inair))

#function takes an array of x values and returns an array of y values
#  where y=mx+b
def func(x, m, b):
    return m*x+b #linear function

yarray=np.asarray(vy_inair)
xarray=np.asarray(t_inair)

constants, stats = curve_fit(func, xarray, yarray)

#constants is a list
mbest=constants[0] #slope
bbest=constants[1] #intercept

print("Best fit: m=",mbest," and b=",bbest)

ybest=func(xarray,mbest,bbest) #y values for best fit function

plt.title('Best fit for v_y(t) for CM while in air')
plt.xlabel('t (s)')
plt.ylabel('v_y,CM (m/s)')
plt.plot(xarray,yarray,'b.',xarray,ybest,'r-')
plt.show()
# Out:
# 0.533
# 0.983
# 17
# 17
# Best fit: m= -4.01586980874  and b= 2.59558253779

# %%
# Momentum 
Px_total = M*Vxcmarray
Py_total = M*Vycmarray 

# Angular Momentum is <0,0,Rx*Py - Ry*Px>
Lz_head = ((x_headarray - xcmarray)*segmass[0]*Vy_headarray - (y_headarray - ycmarray)*segmass[0]*Vx_headarray)*M
Lz_trunk = ((x_trunk - xcmarray)*segmass[1]*Vy_trunk - (y_trunk - ycmarray)*segmass[1]*Vx_trunk)*M
Lz_upper_arm = ((x_upper_arm - xcmarray)*segmass[2]*Vy_upper_arm - (y_upper_arm - ycmarray)*segmass[2]*Vx_upper_arm)*M
Lz_forearm = ((x_forearm - xcmarray)*segmass[3]*Vy_forearm - (y_forearm - ycmarray)*segmass[3]*Vx_forearm)*M
Lz_thigh = ((x_thigh - xcmarray)*segmass[4]*Vy_thigh - (y_thigh - ycmarray)*segmass[4]*Vx_thigh)*M
Lz_leg = ((x_leg - xcmarray)*segmass[5]*Vy_leg - (y_leg - ycmarray)*segmass[5]*Vx_leg)*M

Lz_Rotation = Lz_head + Lz_trunk + Lz_upper_arm + Lz_forearm + Lz_thigh + Lz_leg

# %%
#plot graph
fig2 = plt.figure()
plt.title('Rotational Angular Momentum vs. ' + data_labels[0])
plt.xlabel(data_labels[0])
plt.ylabel("Rotational Angular Momentum (kg*m^2/s)")
plt.plot(tarray,Lz_Rotation,'b-')
plt.show()
